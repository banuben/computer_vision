# %% [markdown]
# <a href="https://colab.research.google.com/github/banuben/computer_vision/blob/main/OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

image = cv2.imread("/content/cat.jpeg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=678x452>

# %%
print("SHAPE", image.shape)

print("HEIGHT", image.shape[0])

print("WIDTH", image.shape[1])

print("CHANNELS", image.shape[2])
# Out:
# SHAPE (452, 678, 3)

# %%
(b, g, r) = image[100, 50]
print("Blue:", b, "Green:", g, "Red:", r)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=678x452>

# %%
resized = cv2.resize(gray, (200, 200))
cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=L size=200x200>

# %%
cropped = gray[100:200, 100:200]
cv2_imshow(cropped)
# Out:
# <PIL.Image.Image image mode=L size=100x100>

# %%
rotated = cv2.rotate(gray, cv2.ROTATE_90_CLOCKWISE)
cv2_imshow(rotated)
# Out:
# <PIL.Image.Image image mode=L size=452x678>

# %%
flipped = cv2.flip(gray, 1)
cv2_imshow(flipped)
# Out:
# <PIL.Image.Image image mode=L size=678x452>

# %%
cv2.imwrite("gray.jpg", gray)
cv2.imwrite("resized.jpg", resized)
cv2.imwrite("cropped.jpg", cropped)
cv2.imwrite("rotated.jpg", rotated)
cv2.imwrite("flipped.jpg", flipped)
